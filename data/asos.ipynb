# %% [markdown]
# https://osf.io/64jsb/wiki/home/

# %%
import pandas as pd

pd.read_csv("./asos_digital_experiments_dataset.csv")
# Out:
# C:\Users\Alexandra\AppData\Local\Temp\ipykernel_13340\2349405931.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#       experiment_id  variant_id  metric_id  time_since_start    count_c  \
# 0            036afc           2          1               1.5   188065.0
# 1            036afc           2          1               2.0   245041.0
# 2            036afc           2          1               2.5   277237.0
# 3            036afc           2          1               3.0   315689.0
# 4            036afc           2          1               3.5   338631.0
# ...
