# %%
import pandas as pd
# Out:
# C:\Users\Alexandra\AppData\Local\Temp\ipykernel_452\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# https://rstudio-pubs-static.s3.amazonaws.com/986404_4dd1a51c486b4c30955a341d938b07ac.html
data = pd.read_csv("./data_viz_website.csv")
data
# Out:
#        visit_date condition  time_spent_homepage_sec  clicked_article  \
# 0      2018-04-01      tips                49.011609                1
# 1      2018-04-01      tips                48.864515                1
# 2      2018-04-01      tips                49.074667                1
# 3      2018-04-01      tips                49.260109                0
# 4      2018-04-01      tips                50.371898                0
# ...           ...       ...                      ...              ...
# 29995  2018-04-30     tools                49.114504                1
# 29996  2018-04-30     tools                49.742075                1
# 29997  2018-04-30     tools                50.649890                1
# 29998  2018-04-30     tools                49.550665                1
# 29999  2018-04-30     tools                50.352502                1
#
#        clicked_like  clicked_share
# 0                 0              1
# 1                 0              0
# ...

# %%
data.condition.unique()
# Out:
# array(['tips', 'tools'], dtype=object)

# %%
import seaborn as sns

# %%
from matplotlib import pyplot as plt

# %%
sns.kdeplot(data[data.condition == 'tools'].time_spent_homepage_sec, label='A') 
sns.kdeplot(data[data.condition == 'tips'].time_spent_homepage_sec, label='B')
plt.legend()

# %%
data.groupby("condition").time_spent_homepage_sec.agg(["count", "median", "max", "mean", "var", "std"])
# Out:
#            count     median        max       mean       var       std
# condition
# tips       15000  50.003084  53.937622  49.999093  1.013412  1.006684
# tools      15000  49.996765  54.023849  49.994889  1.000333  1.000167

# %%
sns.kdeplot(data[data.condition == 'tools'].time_spent_homepage_sec, clip=(49.8, 50.2), color='b', label='A') 
sns.kdeplot(data[data.condition == 'tips'].time_spent_homepage_sec, clip=(49.8, 50.2), color='orange', label='B')
plt.axvline(x=data[data.condition == 'tools'].time_spent_homepage_sec.mean(), color='b')
plt.axvline(x=data[data.condition == 'tips'].time_spent_homepage_sec.mean(), color='orange')
plt.legend()

# %%
# Примеры https://rstudio-pubs-static.s3.amazonaws.com/548733_7473a09d50e94cd4b01e8240a749659b.html
