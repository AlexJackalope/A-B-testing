# %%
import pandas as pd
# Out:
# C:\Users\Alexandra\AppData\Local\Temp\ipykernel_8836\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# https://www.kaggle.com/datasets/tklimonova/grocery-website-data-for-ab-test/data
data = pd.read_csv("./grocery_website.csv")
data
# Out:
#         RecordID    IP Address  LoggedInFlag  ServerID  VisitPageFlag
# 0              1   39.13.114.2             1         2              0
# 1              2     13.3.25.8             1         1              0
# 2              3   247.8.211.8             1         1              0
# 3              4   124.8.220.3             0         3              0
# 4              5   60.10.192.7             0         2              0
# ...          ...           ...           ...       ...            ...
# 184583    184584   114.8.104.1             0         1              0
# 184584    184585   207.2.110.5             0         2              1
# 184585    184586   170.13.31.9             0         2              0
# 184586    184587   195.14.92.3             0         3              0
# 184587    184588  172.12.115.8             0         2              1
#
# [184588 rows x 5 columns]
